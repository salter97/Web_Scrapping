# %%
import pandas as pd

# %%
url = 'https://www.espncricinfo.com/records/year/team-match-results/2022-2022/twenty20-internationals-3'

# %%
all_tables = pd.read_html(url)

# %%
print(len(all_tables))
# Out:
# 1

# %%
all_tables[0]
# Out:
#           Team 1     Team 2       Winner     Margin      Ground    Match Date  \
# 0       Tanzania     Uganda    no result          -      Rwanda  Dec 23, 2022
# 1         Rwanda     Uganda       Uganda     3 runs      Rwanda  Dec 23, 2022
# 2       Malaysia    Bahrain      Bahrain  6 wickets       Bangi  Dec 23, 2022
# 3          Qatar  Singapore        Qatar  9 wickets       Bangi  Dec 23, 2022
# 4       Tanzania     Uganda       Uganda     7 runs      Rwanda  Dec 22, 2022
# ..           ...        ...          ...        ...         ...           ...
# 526  West Indies    England  West Indies    17 runs  Bridgetown  Jan 30, 2022
# 527  West Indies    England      England    34 runs  Bridgetown  Jan 29, 2022
# 528  West Indies    England  West Indies    20 runs  Bridgetown  Jan 26, 2022
# 529  West Indies    England      England      1 run  Bridgetown  Jan 23, 2022
# 530  West Indies    England  West Indies  9 wickets  Bridgetown  Jan 22, 2022
#
#        Scorecard
# 0    T20I # 1983
# 1    T20I # 1982
# 2    T20I # 1981
# 3    T20I # 1980
# 4    T20I # 1979
# ..           ...
# 526  T20I # 1457
# 527  T20I # 1456
# 528  T20I # 1455
# 529  T20I # 1454
# 530  T20I # 1453
#
# [531 rows x 7 columns]

# %%
df = all_tables[0]

# %%
df
# Out:
#           Team 1     Team 2       Winner     Margin      Ground    Match Date  \
# 0       Tanzania     Uganda    no result          -      Rwanda  Dec 23, 2022
# 1         Rwanda     Uganda       Uganda     3 runs      Rwanda  Dec 23, 2022
# 2       Malaysia    Bahrain      Bahrain  6 wickets       Bangi  Dec 23, 2022
# 3          Qatar  Singapore        Qatar  9 wickets       Bangi  Dec 23, 2022
# 4       Tanzania     Uganda       Uganda     7 runs      Rwanda  Dec 22, 2022
# ..           ...        ...          ...        ...         ...           ...
# 526  West Indies    England  West Indies    17 runs  Bridgetown  Jan 30, 2022
# 527  West Indies    England      England    34 runs  Bridgetown  Jan 29, 2022
# 528  West Indies    England  West Indies    20 runs  Bridgetown  Jan 26, 2022
# 529  West Indies    England      England      1 run  Bridgetown  Jan 23, 2022
# 530  West Indies    England  West Indies  9 wickets  Bridgetown  Jan 22, 2022
#
#        Scorecard
# 0    T20I # 1983
# 1    T20I # 1982
# 2    T20I # 1981
# 3    T20I # 1980
# 4    T20I # 1979
# ..           ...
# 526  T20I # 1457
# 527  T20I # 1456
# 528  T20I # 1455
# 529  T20I # 1454
# 530  T20I # 1453
#
# [531 rows x 7 columns]

# %%
df.to_csv('crick_info.csv')
